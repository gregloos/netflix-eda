# %%
#https://www.kaggle.com/datasets/shivamb/netflix-shows
#import libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#importing the datapath and inspecting it

# %%
datapath = "C:\\Users\\gregl\\Desktop\\ML_Projects\\Exploratory Data Analysis\\netflix_titles.csv"
df = pd.read_csv(datapath)
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
#checking the data

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#clearing up null values

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df[df['director'].isna()]
# Out:
#      show_id     type                                title director  \
# 1         s2  TV Show                        Blood & Water      NaN
# 3         s4  TV Show                Jailbirds New Orleans      NaN
# 4         s5  TV Show                         Kota Factory      NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN
# ...      ...      ...                                  ...      ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V      NaN
# 8796   s8797  TV Show                           Yunus Emre      NaN
# 8797   s8798  TV Show                            Zak Storm      NaN
# 8800   s8801  TV Show                   Zindagi Gulzar Hai      NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
df = df.dropna()

# %%
df.head(5)
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
#checking for duplicates

# %%
df[df.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
#reset index

# %%
df.reset_index(drop = True)
# Out:
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5327   s8802    Movie                        Zinzana      Majid Al Ansari
# 5328   s8803    Movie                         Zodiac        David Fincher
# 5329   s8805    Movie                     Zombieland      Ruben Fleischer
# 5330   s8806    Movie                           Zoom         Peter Hewitt
# 5331   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df = df.drop('show_id', axis=1)

# %%
df.head(10)
# Out:
#        type                          title             director  \
# 7     Movie                        Sankofa         Haile Gerima
# 8   TV Show  The Great British Baking Show      Andy Devonshire
# 9     Movie                   The Starling       Theodore Melfi
# 12    Movie                   Je Suis Karl  Christian Schwochow
# 24    Movie                          Jeans           S. Shankar
# 27    Movie                      Grown Ups         Dennis Dugan
# 28    Movie                     Dark Skies        Scott Stewart
# 29    Movie                       Paranoia       Robert Luketic
# 38    Movie            Birth of the Dragon         George Nolfi
# 41    Movie                           Jaws     Steven Spielberg
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
df = df.reset_index()

# %%
df.head(10)
# Out:
#    index     type                          title             director  \
# 0      7    Movie                        Sankofa         Haile Gerima
# 1      8  TV Show  The Great British Baking Show      Andy Devonshire
# 2      9    Movie                   The Starling       Theodore Melfi
# 3     12    Movie                   Je Suis Karl  Christian Schwochow
# 4     24    Movie                          Jeans           S. Shankar
# 5     27    Movie                      Grown Ups         Dennis Dugan
# 6     28    Movie                     Dark Skies        Scott Stewart
# 7     29    Movie                       Paranoia       Robert Luketic
# 8     38    Movie            Birth of the Dragon         George Nolfi
# 9     41    Movie                           Jaws     Steven Spielberg
#
#                                                 cast  \
# 0  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
#Let's make some plots

# %%
#How many movies vs series are in netflix?
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      5185
# TV Show     147
# Name: count, dtype: int64

# %%
df['type'].value_counts().plot(kind='pie', title='Content Type Distribution', autopct='%.1f%%')
plt.axis('equal')
# Out:
# (np.float64(-1.0999998625616536),
#  np.float64(1.0999999934553168),
#  np.float64(-1.0999997100262253),
#  np.float64(1.099999960418613))

# %%
#what is the most common rating?

# %%
df['rating'].unique()
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7',
#        'TV-G', 'TV-Y', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       1822
# TV-14       1214
# R            778
# PG-13        470
# TV-PG        431
# PG           275
# TV-G          84
# TV-Y7         76
# TV-Y          76
# NR            58
# G             40
# TV-Y7-FV       3
# UR             3
# NC-17          2
# Name: count, dtype: int64

# %%
df['rating'].value_counts().plot(kind='bar', title='Ratings distributions')
# Out:
# <Axes: title={'center': 'Ratings distributions'}, xlabel='rating'>

# %%
movies = df[df['type'] == 'Movie'].copy()
duration = movies['duration'].str.split().str[0].astype(int)
sns.kdeplot(duration)
plt.title('Duration of movies')
# Out:
# Text(0.5, 1.0, 'Duration of movies')

# %%
duration.hist()
plt.title('Duration of movies')
# Out:
# Text(0.5, 1.0, 'Duration of movies')

# %%
#let's make a chart for the movies added year by year to see if there was a growth

# %%
movies.head(10)
# Out:
#     index   type                title             director  \
# 0       7  Movie              Sankofa         Haile Gerima
# 2       9  Movie         The Starling       Theodore Melfi
# 3      12  Movie         Je Suis Karl  Christian Schwochow
# 4      24  Movie                Jeans           S. Shankar
# 5      27  Movie            Grown Ups         Dennis Dugan
# 6      28  Movie           Dark Skies        Scott Stewart
# 7      29  Movie             Paranoia       Robert Luketic
# 8      38  Movie  Birth of the Dragon         George Nolfi
# 9      41  Movie                 Jaws     Steven Spielberg
# 10     42  Movie               Jaws 2       Jeannot Szwarc
#
#                                                  cast  \
# 0   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 2   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 3   Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 4   Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...

# %%
movies['date_added'] = pd.to_datetime(
    movies['date_added']
)

# %%
movies['date_added'].head()
# Out:
# 0   2021-09-24
# 2   2021-09-24
# 3   2021-09-23
# 4   2021-09-21
# 5   2021-09-20
# Name: date_added, dtype: datetime64[ns]

# %%
movies['date_added'].dtype
# Out:
# dtype('<M8[ns]')

# %%
movies['year_added'] = movies['date_added'].dt.year

# %%
movies_per_year = movies['year_added'].value_counts().sort_index()

print(movies_per_year)
# Out:
# year_added
# 2008       1
# 2009       2
# 2010       1
# 2011      13
# 2012       3
# 2013       6
# 2014      14
# 2015      47
# 2016     195
# 2017     702
# 2018    1085
# 2019    1236
# 2020    1151
# 2021     729
# Name: count, dtype: int64

# %%
movies_per_year.plot(kind='line', marker='o', title='Movies added to Netflix per year')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.show()

# %%
#lets make a ratings over time chart

# %%
cols = ["type", "rating", "date_added"]
tmp  = df[cols].copy()
tmp["date_added"] = pd.to_datetime(tmp["date_added"], errors="coerce")
tmp["year_added"] = tmp["date_added"].dt.year

pivot = (
    tmp
    .groupby(["year_added", "rating"])
    .size()
    .unstack(fill_value=0)
    .sort_index()
)

# %%
ax = pivot.plot.area(stacked=True, figsize=(10,6), alpha=0.8)
ax.set_title("Netflix catalogue growth by rating")
ax.set_xlabel("Year added")
ax.set_ylabel("Number of titles")
ax.legend(title="Rating", bbox_to_anchor=(1.05,1), loc="upper left")
plt.tight_layout()

# %%
g = df[["date_added", "listed_in"]].copy()
